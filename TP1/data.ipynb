# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_high = pd.read_csv('High_RE_2030_efficiency1_dissipation0.5_value.csv')
df_mid = pd.read_csv('MidCase_2030_efficiency1_dissipation0.5_value.csv')
df_low = pd.read_csv('Low_RE_2030_efficiency1.25_dissipation0.5_value.csv')

# %%
# Combinar os datasets
df_combined = pd.concat([df_high, df_mid, df_low], ignore_index=True)

# %%
df_combined['local_datetime'] = pd.to_datetime(df_combined['local_datetime'], errors='coerce', utc=True)

# %%
# Criação de novas colunas para ano e mês
df_combined['year'] = df_combined['local_datetime'].dt.year
df_combined['month'] = df_combined['local_datetime'].dt.month

# %%
# Remover as colunas irrelevantes e com valores NaN e 0
df_combined = df_combined.drop(['local_orig_h', 'local_shift_to', 'max_post_shift', 'flex'], axis=1)

# %%
df_cleaned = df_combined.dropna()
# Remover linhas com valores 0 em qualquer coluna
df_cleaned = df_cleaned[(df_cleaned != 0).all(axis=1)]

# %%
df_cleaned.head(30)
# Out:
#       region  max_pre_shift            local_datetime     energy   capacity  \
# 38503   AZNM           12.0 2030-06-29 03:00:00+00:00   4.087961   9.218094
# 38505   AZNM           12.0 2030-07-01 03:00:00+00:00   0.101755   3.508876
# 38514   AZNM           12.0 2030-07-10 03:00:00+00:00  -2.927637   3.666783
# 38544   AZNM           12.0 2030-08-09 03:00:00+00:00  -2.964702  13.058011
# 38545   AZNM           12.0 2030-08-10 03:00:00+00:00 -11.365569  23.368670
# 38909   CAMX           12.0 2030-08-09 03:00:00+00:00  -2.957989   9.156791
# 38910   CAMX           12.0 2030-08-10 03:00:00+00:00 -11.363185  15.576547
# 38911   CAMX           12.0 2030-08-11 03:00:00+00:00 -15.112459  21.918456
# 38912   CAMX           12.0 2030-08-12 03:00:00+00:00 -18.338677  18.581032
# 38915   CAMX           12.0 2030-08-15 03:00:00+00:00 -15.142152  27.107618
# 40890   NWPP           12.0 2030-01-12 03:00:00+00:00   2.120896   4.709395
# 41063   NWPP           12.0 2030-07-04 03:00:00+00:00  -0.054007   6.635698
# 41078   NWPP           12.0 2030-07-19 03:00:00+00:00   1.568148   0.992990
# 41080   NWPP           12.0 2030-07-21 03:00:00+00:00  -0.619412   0.836367
# 43253   RMPA           12.0 2030-07-04 03:00:00+00:00  -0.404080   0.534036
# 43268   RMPA           12.0 2030-07-19 03:00:00+00:00  -6.096171   9.110715
# 43275   RMPA           12.0 2030-07-26 03:00:00+00:00  -7.809850   8.043439
# 43276   RMPA           12.0 2030-07-27 03:00:00+00:00  -0.568718   1.563582
# 48555   NWPP            1.0 2030-01-11 15:00:00+00:00  -0.845205  10.588077
# 53833   AZNM            1.0 2030-06-29 03:00:00+00:00   0.612890   9.218094
# 53835   AZNM            1.0 2030-07-01 03:00:00+00:00   0.101755   3.508876
# 53874   AZNM            1.0 2030-08-09 03:00:00+00:00  -2.964702  13.058011
# 54239   CAMX            1.0 2030-08-09 03:00:00+00:00  -2.957989   9.156791
# 56393   NWPP            1.0 2030-07-04 03:00:00+00:00  -0.054007   6.635698
# 56410   NWPP            1.0 2030-07-21 03:00:00+00:00  -0.619412   0.836367
# 58583   RMPA            1.0 2030-07-04 03:00:00+00:00  -0.404080   0.534036
# 58598   RMPA            1.0 2030-07-19 03:00:00+00:00  -6.096171   9.110715
# 58606   RMPA            1.0 2030-07-27 03:00:00+00:00  -0.568718   1.563582
# 63886   NWPP            1.0 2030-01-12 14:00:00+00:00   0.816451  17.579546
# 63887   NWPP            1.0 2030-01-13 14:00:00+00:00  -2.407776  15.328739
#
#        shifting_value      spin       reg  total_profit  year  month
# 38503       13.306055  0.160700  0.057655     13.306055  2030      6
# 38505        3.610631  0.160599  0.058899      3.610631  2030      7
# 38514        0.739146  0.159766  0.056679      0.739146  2030      7
# 38544       10.093309  0.166551  0.056847     10.093309  2030      8
# 38545       12.003101  0.148418  0.050607     12.003101  2030      8
# 38909        6.198802  0.166929  0.056139      6.198802  2030      8
# 38910        4.213362  0.151379  0.050991      4.213362  2030      8
# 38911        6.805997  0.158970  0.053670      6.805997  2030      8
# 38912        0.242354  0.004256  0.001442      0.242354  2030      8
# 38915       11.965465  0.162539  0.055203     11.965465  2030      8
# 40890        6.830291  0.031325  0.018070      6.830291  2030      1
# 41063        6.581691  0.161694  0.063616      6.581691  2030      7
# 41078        2.561138  0.028469  0.010620      2.561138  2030      7
# 41080        0.216955  0.167433  0.062219      0.216955  2030      7
# 43253        0.129955  0.005730  0.066269      0.237210  2030      7
# 43268        3.014544  0.042739  0.015608      3.014544  2030      7
# 43275        0.233589  0.184484  0.071058      0.233589  2030      7
# 43276        0.994864  0.181740  0.067176      0.994864  2030      7
# 48555        9.742872  0.142236  0.078707      9.742872  2030      1
# 53833        9.830985  0.160700  0.057655      9.830985  2030      6
# 53835        3.610631  0.160599  0.058899      3.610631  2030      7
# 53874       10.093309  0.166551  0.056847     10.093309  2030      8
# 54239        6.198802  0.166929  0.056139      6.198802  2030      8
# 56393        6.581691  0.161694  0.063616      6.581691  2030      7
# 56410        0.216955  0.167433  0.062219      0.216955  2030      7
# 58583        0.129955  0.005730  0.066269      0.237210  2030      7
# 58598        3.014544  0.042739  0.015608      3.014544  2030      7
# 58606        0.994864  0.181740  0.067176      0.994864  2030      7
# 63886       18.395996  0.110969  0.060299     18.395996  2030      1
# 63887       12.920963  0.084333  0.040733     12.920963  2030      1

# %%
# Salvar o dataframe tratado
df_cleaned.to_csv('cleaned_energy_data.csv', index=False)

# %%
df_numerical = df_cleaned.select_dtypes(include=['float64', 'int64'])

# %%
corr = df_numerical.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlação das Variáveis Numéricas')
plt.show()

# %%
# Calcular eficiência energética (lucro por unidade de energia)
df_cleaned['efficiency'] = df_cleaned['total_profit'] / df_cleaned['energy']

# %%
df_cleaned.describe()
# Out:
#        max_pre_shift       energy     capacity  shifting_value         spin  \
# count    4353.000000  4353.000000  4353.000000     4353.000000  4353.000000
# mean        6.365036   -13.198904    63.785079       50.586175     0.053133
# std         4.615127    25.057364    76.223617       64.724657     0.062569
# min         1.000000  -275.075379    -3.343535        0.002462     0.000083
# 25%         4.000000   -12.720928    11.226520        6.830291     0.007426
# 50%         4.000000    -5.573518    34.400822       25.005203     0.016799
# 75%        12.000000    -2.479459    88.216400       70.082339     0.111416
# max        12.000000    14.339950   612.658196      600.595817     0.207747
#
#                reg  total_profit         year        month    efficiency
# count  4353.000000   4353.000000  4353.000000  4353.000000   4353.000000
# mean      0.020259     50.586653  2030.003216     6.815989     12.899517
# std       0.023539     64.724284     0.056627     2.010748    607.362496
# min       0.000029      0.005259  2030.000000     1.000000  -1697.787735
# 25%       0.002652      6.830291  2030.000000     7.000000     -8.162374
# 50%       0.006628     25.005203  2030.000000     7.000000     -2.619367
# 75%       0.048407     70.082339  2030.000000     8.000000     -0.563858
# max       0.094670    600.595817  2031.000000    12.000000  21799.655763

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4353 entries, 38503 to 1655278
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          4353 non-null   object
#  1   max_pre_shift   4353 non-null   float64
#  2   local_datetime  4353 non-null   datetime64[ns, UTC]
#  3   energy          4353 non-null   float64
#  4   capacity        4353 non-null   float64
#  5   shifting_value  4353 non-null   float64
#  6   spin            4353 non-null   float64
#  7   reg             4353 non-null   float64
#  8   total_profit    4353 non-null   float64
#  9   year            4353 non-null   int32
#  10  month           4353 non-null   int32
#  11  efficiency      4353 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(8), int32(2), object(1)
# memory usage: 408.1+ KB

# %%
# Definir uma função para remover outliers com base no IQR
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_filtered

# Remover outliers de várias colunas
df_cleaned = remove_outliers_iqr(df_cleaned, 'energy')
df_cleaned = remove_outliers_iqr(df_cleaned, 'capacity')
df_cleaned = remove_outliers_iqr(df_cleaned, 'total_profit')

# %%
# Verificar a distribuição da eficiência por região

# Adicionar uma linha de referência para a mediana geral
median_efficiency = df_cleaned['efficiency'].median()


plt.figure(figsize=(10, 6))
sns.boxplot(x='region', y='efficiency', data=df_cleaned, palette="Set2")
plt.yscale('log')  # Usar escala logarítmica no eixo Y
sns.stripplot(x='region', y='efficiency', data=df_cleaned, color='black', alpha=0.5)
plt.axhline(median_efficiency, color='red', linestyle='--', label=f'Mediana Geral: {median_efficiency:.2f}')
plt.title('Distribuição da Eficiência por Região (após limpeza)')
plt.xlabel('Região')
plt.ylabel('Eficiência (Lucro por kWh)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Dani\AppData\Local\Temp\ipykernel_32428\2387569710.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region', y='efficiency', data=df_cleaned, palette="Set2")

# %%
# Ordenar as regiões pela média de eficiência
df_region_efficiency = df_cleaned.groupby('region')['efficiency'].mean().reset_index()
df_region_efficiency = df_region_efficiency.sort_values(by='efficiency', ascending=False)

# Definir uma paleta de cores personalizada
palette = sns.color_palette("Blues_d", len(df_region_efficiency))

# Criar o gráfico de barras
plt.figure(figsize=(12, 6))
sns.barplot(x='region', y='efficiency', data=df_region_efficiency, palette=palette)

# Adicionar anotações para os valores de eficiência
for index, value in enumerate(df_region_efficiency['efficiency']):
    plt.text(index, value + 0.01, f'{value:.2f}', ha='center', va='bottom')

# Melhorar os títulos e rótulos
plt.title('Média de Eficiência Energética por Região (Lucro por kWh)', fontsize=16, fontweight='bold')
plt.xlabel('Região', fontsize=12)
plt.ylabel('Eficiência (Lucro por kWh)', fontsize=12)

# Rotacionar os rótulos das regiões para facilitar a leitura
plt.xticks(rotation=45, ha='right')

# Mostrar o gráfico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dani\AppData\Local\Temp\ipykernel_32428\3635149441.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='region', y='efficiency', data=df_region_efficiency, palette=palette)

# %%
df_monthly = df_cleaned.groupby('month')[['energy', 'total_profit']].mean().reset_index()

# Configurações de estilo
sns.set(style="whitegrid")

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))

# Plotar energia
sns.lineplot(x='month', y='energy', data=df_monthly, marker='o', label='Energy', color='blue', linewidth=2.5)
# Plotar lucro total
sns.lineplot(x='month', y='total_profit', data=df_monthly, marker='s', label='Total Profit', color='green', linewidth=2.5)

# Adicionar títulos e rótulos aprimorados
plt.title('Evolução da Energia e Lucro ao Longo de 2030 (após limpeza)', fontsize=16, fontweight='bold')
plt.xlabel('Mês', fontsize=14)
plt.ylabel('Valor Médio', fontsize=14)

# Destacar os valores máximos e mínimos
max_energy = df_monthly['energy'].max()
min_energy = df_monthly['energy'].min()
max_profit = df_monthly['total_profit'].max()
min_profit = df_monthly['total_profit'].min()

# Anotação para energia
plt.text(df_monthly['month'][df_monthly['energy'].idxmax()], max_energy, f'Máx: {max_energy:.2f}', 
         horizontalalignment='left', color='blue', fontsize=12)
plt.text(df_monthly['month'][df_monthly['energy'].idxmin()], min_energy, f'Mín: {min_energy:.2f}', 
         horizontalalignment='left', color='blue', fontsize=12)

# Anotação para lucro
plt.text(df_monthly['month'][df_monthly['total_profit'].idxmax()], max_profit, f'Máx: {max_profit:.2f}', 
         horizontalalignment='left', color='green', fontsize=12)
plt.text(df_monthly['month'][df_monthly['total_profit'].idxmin()], min_profit, f'Mín: {min_profit:.2f}', 
         horizontalalignment='left', color='green', fontsize=12)

# Melhorar a legenda
plt.legend(title='Métricas', title_fontsize='13', fontsize='12', loc='upper left', bbox_to_anchor=(1, 1))

# Exibir o gráfico
plt.tight_layout()
plt.show()

# %%
# Verificar o dataset após a remoção de outliers
print(df_cleaned.describe())
# Out:
#        max_pre_shift       energy     capacity  shifting_value         spin  \
# count    3433.000000  3433.000000  3433.000000     3433.000000  3433.000000
# mean        5.964754    -5.500474    33.110651       27.610177     0.054647
# std         4.639471     6.579262    31.342324       28.750588     0.063549
# min         1.000000   -27.951443    -3.343535        0.002462     0.000083
# 25%         1.000000    -6.868063     8.185798        4.886881     0.007438
# 50%         4.000000    -3.369903    21.479174       15.523853     0.017418
# 75%        12.000000    -1.697951    50.574754       43.210815     0.122934
# max        12.000000    11.773757   138.797582      115.322019     0.207747
#
#                reg  total_profit         year        month    efficiency
# count  3433.000000   3433.000000  3433.000000  3433.000000   3433.000000
# mean      0.021200     27.610784  2030.004078     6.822022     19.574896
# std       0.024176     28.750008     0.063739     2.060581    683.660166
# min       0.000029      0.005259  2030.000000     1.000000  -1697.787735
# 25%       0.002685      4.886881  2030.000000     7.000000     -7.189000
# 50%       0.006959     15.523853  2030.000000     7.000000     -2.267605
# 75%       0.052390     43.210815  2030.000000     8.000000     -0.412212
# max       0.094670    115.322019  2031.000000    12.000000  21799.655763

# %%
file_path = 'D:\Pastas\Infnet\Infnet - 2024.2\Projeto de bloco\TP1\Dados_abertos_Consumo_Mensal.xlsx'

# %%
xls = pd.ExcelFile(file_path)
sheet_names = xls.sheet_names

# %%
data_frames = {sheet: pd.read_excel(xls, sheet_name=sheet) for sheet in sheet_names}

# %%
for sheet_name, df in data_frames.items():
    print(f"Explorando a planilha: {sheet_name}\n")
    
    # Mostrar as primeiras linhas
    print("Primeiras linhas:")
    print(df.head(), "\n")
    
    # Mostrar as últimas linhas
    print("Últimas linhas:")
    print(df.tail(), "\n")
    
    # Resumo estatístico
    print("Resumo estatístico:")
    print(df.describe(), "\n")
    
    # Informações sobre os tipos de dados
    print("Informações dos dados:")
    print(df.info(), "\n")
    
    # Contagem de valores únicos
    print("Valores únicos por coluna:")
    unique_counts = {col: df[col].nunique() for col in df.columns}
    print(unique_counts, "\n\n")
# Out:
# Explorando a planilha: CONSUMO E NUMCONS SAM
#
# Primeiras linhas:
#        Data  DataExcel        Regiao                   Sistema      Classe  \
# 0  20240801 2024-08-01  Centro-Oeste  SUDESTE / CENTRO - OESTE   Comercial
# 1  20240801 2024-08-01  Centro-Oeste  SUDESTE / CENTRO - OESTE   Comercial
# 2  20240801 2024-08-01  Centro-Oeste  SUDESTE / CENTRO - OESTE  Industrial
# 3  20240801 2024-08-01  Centro-Oeste  SUDESTE / CENTRO - OESTE  Industrial
# 4  20240801 2024-08-01  Centro-Oeste  SUDESTE / CENTRO - OESTE      Outros
#
#   TipoConsumidor     Consumo  Consumidores
# 0         Cativo  420910.578      503275.0
# 1          Livre  200873.852        2244.0
# 2         Cativo   93217.614       31383.0
# 3          Livre  948142.657         967.0
# 4         Cativo  329593.825       63241.0
#
# Últimas linhas:
#            Data  DataExcel Regiao Sistema       Classe TipoConsumidor  \
# 16811  20040101 2004-01-01    Sul     SUL   Industrial         Cativo
# 16812  20040101 2004-01-01    Sul     SUL   Industrial          Livre
# 16813  20040101 2004-01-01    Sul     SUL       Outros         Cativo
# 16814  20040101 2004-01-01    Sul     SUL  Residencial         Cativo
# 16815  20040101 2004-01-01    Sul     SUL        Rural         Cativo
#
#            Consumo  Consumidores
# 16811  1464696.468      159190.0
# 16812   346283.691          42.0
# 16813   373249.407       84291.0
# 16814  1132506.000     6762504.0
# 16815   489375.701      814350.0
#
# Resumo estatístico:
#                Data                      DataExcel       Consumo  Consumidores
# count  1.681600e+04                          16816  1.681600e+04  1.681600e+04
# mean   2.014580e+07  2014-12-19 20:45:31.684110336  5.450955e+05  1.096585e+06
# min    2.004010e+07            2004-01-01 00:00:00 -2.210000e+02  0.000000e+00
# 25%    2.010020e+07            2010-02-01 00:00:00  1.226918e+04  1.197500e+02
# 50%    2.015050e+07            2015-05-01 00:00:00  1.233574e+05  1.572300e+04
# 75%    2.020010e+07            2020-01-01 00:00:00  5.763647e+05  2.479560e+05
# max    2.024080e+07            2024-08-01 00:00:00  8.227587e+06  3.646215e+07
# std    5.861524e+04                            NaN  1.072158e+06  4.150135e+06
#
# Informações dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16816 entries, 0 to 16815
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            16816 non-null  int64
#  1   DataExcel       16816 non-null  datetime64[ns]
#  2   Regiao          16816 non-null  object
#  3   Sistema         16816 non-null  object
#  4   Classe          16816 non-null  object
#  5   TipoConsumidor  16816 non-null  object
#  6   Consumo         16816 non-null  float64
#  7   Consumidores    16816 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 1.0+ MB
# None
#
# Valores únicos por coluna:
# {'Data': 248, 'DataExcel': 248, 'Regiao': 5, 'Sistema': 5, 'Classe': 5, 'TipoConsumidor': 2, 'Consumo': 15554, 'Consumidores': 11140}
#
#
# Explorando a planilha: CONSUMO E NUMCONS SAM UF
#
# Primeiras linhas:
#        Data  DataExcel  UF Regiao            Sistema       Classe  \
# 0  20240701 2024-07-01  AC  Norte  SISTEMAS ISOLADOS    Comercial
# 1  20240701 2024-07-01  AC  Norte  SISTEMAS ISOLADOS   Industrial
# 2  20240701 2024-07-01  AC  Norte  SISTEMAS ISOLADOS       Outros
# 3  20240701 2024-07-01  AC  Norte  SISTEMAS ISOLADOS  Residencial
# 4  20240701 2024-07-01  AC  Norte  SISTEMAS ISOLADOS        Rural
#
#   TipoConsumidor   Consumo  Consumidores
# 0         Cativo  3836.230        3808.0
# 1         Cativo   346.759          34.0
# 2         Cativo  3791.186        1140.0
# 3         Cativo  8273.041       46855.0
# 4         Cativo  1499.150        2664.0
#
# Últimas linhas:
#            Data  DataExcel  UF Regiao            Sistema       Classe  \
# 54562  20040101 2004-01-01  TO  Norte  NORTE INTERLIGADO    Comercial
# 54563  20040101 2004-01-01  TO  Norte  NORTE INTERLIGADO   Industrial
# 54564  20040101 2004-01-01  TO  Norte  NORTE INTERLIGADO       Outros
# 54565  20040101 2004-01-01  TO  Norte  NORTE INTERLIGADO  Residencial
# 54566  20040101 2004-01-01  TO  Norte  NORTE INTERLIGADO        Rural
#
#       TipoConsumidor    Consumo  Consumidores
# 54562         Cativo  13832.427       26181.0
# 54563         Cativo   6545.226        2416.0
# 54564         Cativo  15333.919        5801.0
# 54565         Cativo  25505.307      232464.0
# 54566         Cativo   4659.728       16083.0
#
# Resumo estatístico:
#                Data                      DataExcel       Consumo  Consumidores
# count  5.456700e+04                          54567  5.456700e+04  5.456700e+04
# mean   2.014548e+07  2014-12-07 23:39:51.885205504  1.671426e+05  3.362200e+05
# min    2.004010e+07            2004-01-01 00:00:00 -2.877090e+02  0.000000e+00
# 25%    2.009120e+07            2009-12-01 00:00:00  8.754739e+03  1.605000e+02
# 50%    2.015050e+07            2015-05-01 00:00:00  4.814400e+04  1.020500e+04
# 75%    2.020030e+07            2020-03-01 00:00:00  1.529405e+05  1.047670e+05
# max    2.024070e+07            2024-07-01 00:00:00  4.328005e+06  1.947038e+07
# std    5.942231e+04                            NaN  3.846355e+05  1.340243e+06
#
# Informações dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54567 entries, 0 to 54566
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Data            54567 non-null  int64
#  1   DataExcel       54567 non-null  datetime64[ns]
#  2   UF              54567 non-null  object
#  3   Regiao          54567 non-null  object
#  4   Sistema         54567 non-null  object
#  5   Classe          54567 non-null  object
#  6   TipoConsumidor  54567 non-null  object
#  7   Consumo         54567 non-null  float64
#  8   Consumidores    54567 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 3.7+ MB
# None
#
# Valores únicos por coluna:
# {'Data': 247, 'DataExcel': 247, 'UF': 27, 'Regiao': 5, 'Sistema': 5, 'Classe': 5, 'TipoConsumidor': 2, 'Consumo': 49000, 'Consumidores': 32021}
#
#
# Explorando a planilha: SETOR INDUSTRIAL POR RG
#
# Primeiras linhas:
#        Data  DataExcel                      SetorIndustrial        Regiao  \
# 0  20240801 2024-08-01  07 - EXTRAÇÃO DE MINERAIS METÁLICOS  Centro-Oeste
# 1  20240801 2024-08-01  07 - EXTRAÇÃO DE MINERAIS METÁLICOS      Nordeste
# 2  20240801 2024-08-01  07 - EXTRAÇÃO DE MINERAIS METÁLICOS         Norte
# 3  20240801 2024-08-01  07 - EXTRAÇÃO DE MINERAIS METÁLICOS       Sudeste
# 4  20240801 2024-08-01  07 - EXTRAÇÃO DE MINERAIS METÁLICOS           Sul
#
#       Consumo
# 0   71851.820
# 1  134083.162
# 2  338042.627
# 3  781204.021
# 4     814.212
#
# Últimas linhas:
#           Data  DataExcel                                    SetorIndustrial  \
# 7595  20120101 2012-01-01  29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQ...
# 7596  20120101 2012-01-01  29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQ...
# 7597  20120101 2012-01-01  29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQ...
# 7598  20120101 2012-01-01  29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQ...
# 7599  20120101 2012-01-01  29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQ...
#
#             Regiao   Consumo
# 7595  Centro-Oeste    4041.0
# 7596      Nordeste   17612.0
# 7597         Norte      45.0
# 7598       Sudeste  429356.0
# 7599           Sul   91347.0
#
# Resumo estatístico:
#                Data                      DataExcel       Consumo
# count  7.600000e+03                           7600  7.600000e+03
# mean   2.017906e+07  2018-04-16 17:03:09.473684224  2.402579e+05
# min    2.012010e+07            2012-01-01 00:00:00  4.500000e+01
# 25%    2.015028e+07            2015-02-22 00:00:00  2.147971e+04
# 50%    2.018045e+07            2018-04-16 00:00:00  1.345466e+05
# 75%    2.021063e+07            2021-06-08 12:00:00  2.986131e+05
# max    2.024080e+07            2024-08-01 00:00:00  2.483892e+06
# std    3.658701e+04                            NaN  3.476410e+05
#
# Informações dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7600 entries, 0 to 7599
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Data             7600 non-null   int64
#  1   DataExcel        7600 non-null   datetime64[ns]
#  2   SetorIndustrial  7600 non-null   object
#  3   Regiao           7600 non-null   object
#  4   Consumo          7600 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 297.0+ KB
# None
#
# Valores únicos por coluna:
# {'Data': 152, 'DataExcel': 152, 'SetorIndustrial': 10, 'Regiao': 5, 'Consumo': 7538}
#
#
# Explorando a planilha: CONSUMO_BEN_RG_1970-1989
#
# Primeiras linhas:
#     Ano Regiao       Classe  Consumo
# 0  1970  Norte  Residencial   173000
# 1  1971  Norte  Residencial   201000
# 2  1972  Norte  Residencial   241000
# 3  1973  Norte  Residencial   281000
# 4  1974  Norte  Residencial   329000
#
# Últimas linhas:
#       Ano   Regiao  Classe   Consumo
# 395  1985  Sudeste  Outros  10006841
# 396  1986  Sudeste  Outros  10374886
# 397  1987  Sudeste  Outros  11052626
# 398  1988  Sudeste  Outros  13299637
# 399  1989  Sudeste  Outros  14718385
#
# Resumo estatístico:
#                Ano       Consumo
# count   400.000000  4.000000e+02
# mean   1979.500000  5.444211e+06
# std       5.773503  1.043857e+07
# min    1970.000000  5.725600e+04
# 25%    1974.750000  7.080900e+05
# 50%    1979.500000  1.740751e+06
# 75%    1984.250000  5.362701e+06
# max    1989.000000  6.971316e+07
#
# Informações dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ano      400 non-null    int64
#  1   Regiao   400 non-null    object
#  2   Classe   400 non-null    object
#  3   Consumo  400 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 12.6+ KB
# None
#
# Valores únicos por coluna:
# {'Ano': 20, 'Regiao': 5, 'Classe': 4, 'Consumo': 399}
#
#
# Explorando a planilha: CONSUMO_ELETROBRAS_1990-2003
#
# Primeiras linhas:
#        Data  DataExcel        Regiao       Classe   Consumo  Consumidores
# 0  19900101      32874  Centro-Oeste    Comercial  138203.0             0
# 1  19900101      32874  Centro-Oeste   Industrial  151652.0             0
# 2  19900101      32874  Centro-Oeste       Outros  123037.0        259143
# 3  19900101      32874  Centro-Oeste  Residencial  248024.0       1460579
# 4  19900101      32874  Centro-Oeste        Rural   25402.0             0
#
# Últimas linhas:
#           Data  DataExcel Regiao       Classe      Consumo  Consumidores
# 4195  20031201      37956    Sul    Comercial   692374.000             0
# 4196  20031201      37956    Sul   Industrial  1859918.000             0
# 4197  20031201      37956    Sul       Outros   387987.765       1753192
# 4198  20031201      37956    Sul  Residencial  1066287.000       6762382
# 4199  20031201      37956    Sul        Rural   426580.000             0
#
# Resumo estatístico:
#                Data     DataExcel       Consumo  Consumidores
# count  4.200000e+03   4200.000000  4.200000e+03  4.200000e+03
# mean   1.996565e+07  35414.678571  8.565816e+05  1.618944e+06
# std    4.031757e+04   1476.278305  1.252415e+06  3.790262e+06
# min    1.990010e+07  32874.000000  2.059000e+03  0.000000e+00
# 25%    1.993068e+07  34143.500000  1.789525e+05  0.000000e+00
# 50%    1.996565e+07  35415.500000  3.697020e+05  0.000000e+00
# 75%    2.000063e+07  36685.500000  1.025958e+06  1.439754e+06
# max    2.003120e+07  37956.000000  6.751722e+06  2.225662e+07
#
# Informações dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4200 entries, 0 to 4199
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Data          4200 non-null   int64
#  1   DataExcel     4200 non-null   int64
#  2   Regiao        4200 non-null   object
#  3   Classe        4200 non-null   object
#  4   Consumo       4200 non-null   float64
#  5   Consumidores  4200 non-null   int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 197.0+ KB
# None
#
# Valores únicos por coluna:
# {'Data': 168, 'DataExcel': 168, 'Regiao': 5, 'Classe': 5, 'Consumo': 4197, 'Consumidores': 1681}
#
#
# Explorando a planilha: ANALISE CONS NUMCONS SAM
#
# Primeiras linhas:
#     Soma de Consumo    Rótulos de Coluna           Unnamed: 2  \
# 0  Rótulos de Linha  2023-01-01 00:00:00  2023-02-01 00:00:00
# 1      Centro-Oeste          3240419.236          3236576.917
# 2          Nordeste          7661411.114          7494725.054
# 3             Norte          3179390.004          2962216.697
# 4           Sudeste         20159474.471         20704476.363
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0  2023-03-01 00:00:00  2023-04-01 00:00:00  2023-05-01 00:00:00
# 1           3443925.86          3510642.333          3377696.041
# 2          7914538.804           7809121.78          7940968.167
# {'Soma de Consumo': 7, 'Rótulos de Coluna': 7, 'Unnamed: 2': 7, 'Unnamed: 3': 7, 'Unnamed: 4': 7, 'Unnamed: 5': 7, 'Unnamed: 6': 7, 'Unnamed: 7': 7, 'Unnamed: 8': 7, 'Unnamed: 9': 7, 'Unnamed: 10': 7, 'Unnamed: 11': 7, 'Unnamed: 12': 7, 'Unnamed: 13': 7, 'Unnamed: 14': 7, 'Unnamed: 15': 7, 'Unnamed: 16': 7, 'Unnamed: 17': 7, 'Unnamed: 18': 7, 'Unnamed: 19': 7, 'Unnamed: 20': 7, 'Unnamed: 21': 7}
#
#
# Explorando a planilha: ANALISE CONS NUMCONS SAM UF
#
# Primeiras linhas:
#   Soma de Consumo            DataExcel           Unnamed: 2  \
# 0              UF  2023-01-01 00:00:00  2023-02-01 00:00:00
# 1              AC            96232.465            90887.219
# 2              AL           469346.617           430041.121
# 3              AM               533209               497067
# 4              AP            86295.028            78650.101
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0  2023-03-01 00:00:00  2023-04-01 00:00:00  2023-05-01 00:00:00
# 1            97753.695            93723.095            98917.413
# 2           475804.099           474164.162           459426.974
# 3               570246               562062               600753
# 4            87422.472            90204.453           101781.177
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0  2023-06-01 00:00:00  2023-07-01 00:00:00  2023-08-01 00:00:00
# 1            97588.352            99208.354           111051.632
# 2            444615.97           399693.496           398214.325
# 3               596287               629670               679809
# 4            99767.299           102849.895           107499.754
#
#             Unnamed: 9  ...          Unnamed: 11          Unnamed: 12  \
# 0  2023-09-01 00:00:00  ...  2023-11-01 00:00:00  2023-12-01 00:00:00
# 1           117116.696  ...           117852.583           113007.964
# 2           441572.715  ...           487945.716           499626.899
# 3               682470  ...               653955               598571
# 4            109182.93  ...           126924.816           117726.317
#
#            Unnamed: 13          Unnamed: 14          Unnamed: 15  \
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00
# 1           109695.372           104112.846           104085.465
# 2           510976.465           484099.543           539350.257
# 3               617703               622250               639770
# 4           109754.747           107885.129           105896.842
#
#            Unnamed: 16          Unnamed: 17          Unnamed: 18  \
# 0  2024-04-01 00:00:00  2024-05-01 00:00:00  2024-06-01 00:00:00
# 1           114835.173           113443.054           101217.722
# 2           474724.706           460361.459            427272.53
# 3               638760               653774               636390
# 4           111785.457           113301.283           113263.985
#
#            Unnamed: 19  Unnamed: 20
# 0  2024-07-01 00:00:00  Total Geral
# 1           103114.782  2000446.593
# 2           437674.916   8768812.11
# 3               686657     11779586
# 4            115691.04  1998171.833
#
# [5 rows x 21 columns]
#
# Últimas linhas:
#    Soma de Consumo     DataExcel    Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 24              SC   2481667.038   2697022.118   2779518.646    2588328.18
# 25              SE    342141.954    327801.348    352982.685    330558.741
# 26              SP  11286108.073  11540029.553  11841790.835  12070175.188
# 27              TO     198836.99    198301.142    223356.817    223609.043
# 28     Total Geral  42540172.136  43021361.135  45723196.294  44884945.911
#
#       Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 
#  20  Unnamed: 20      29 non-null     object
# dtypes: object(21)
# memory usage: 4.9+ KB
# None
#
# Valores únicos por coluna:
# {'Soma de Consumo': 29, 'DataExcel': 29, 'Unnamed: 2': 29, 'Unnamed: 3': 29, 'Unnamed: 4': 29, 'Unnamed: 5': 29, 'Unnamed: 6': 29, 'Unnamed: 7': 29, 'Unnamed: 8': 29, 'Unnamed: 9': 29, 'Unnamed: 10': 29, 'Unnamed: 11': 29, 'Unnamed: 12': 29, 'Unnamed: 13': 29, 'Unnamed: 14': 29, 'Unnamed: 15': 29, 'Unnamed: 16': 29, 'Unnamed: 17': 29, 'Unnamed: 18': 29, 'Unnamed: 19': 29, 'Unnamed: 20': 29}
#
#
# Explorando a planilha: ANALISE SETOR IND POR RG
#
# Primeiras linhas:
#                                  Unnamed: 0           Unnamed: 1  \
# 0                                       NaN                  NaN
# 1                           Soma de Consumo    Rótulos de Coluna
# 2                          Rótulos de Linha  2023-01-01 00:00:00
# 3       07 - EXTRAÇÃO DE MINERAIS METÁLICOS          1101347.366
# 4  10 - FABRICAÇÃO DE PRODUTOS ALIMENTÍCIOS          2103402.941
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2023-02-01 00:00:00  2023-03-01 00:00:00  2023-04-01 00:00:00
# 3           996585.672          1139503.584          1103973.016
# 4          2052408.327          2132254.434          2122638.063
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2023-05-01 00:00:00  2023-06-01 00:00:00  2023-07-01 00:00:00
# 3          1197595.065          1192146.689          1155128.962
# 4          2082143.197          2064909.666          2076029.959
#
#             Unnamed: 8           Unnamed: 9  ...          Unnamed: 12  \
# 0                  NaN                  NaN  ...                  NaN
# 1                  NaN                  NaN  ...                  NaN
# 2  2023-08-01 00:00:00  2023-09-01 00:00:00  ...  2023-12-01 00:00:00
# 3          1193786.943          1183868.475  ...          1215281.248
# 4          2170647.173          2167065.418  ...          2186466.392
#
#            Unnamed: 13          Unnamed: 14          Unnamed: 15  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00
# 3          1177561.146          1100118.284           1132409.56
# 4          2177658.692          2175018.621          2229240.163
#
#            Unnamed: 16          Unnamed: 17          Unnamed: 18  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2  2024-04-01 00:00:00  2024-05-01 00:00:00  2024-06-01 00:00:00
# 3          1128056.194          1189553.702          1190878.907
# 4           2268924.33          2243552.626          2165572.919
#
#            Unnamed: 19          Unnamed: 20   Unnamed: 21
# 0                  NaN                  NaN           NaN
# 1                  NaN                  NaN           NaN
# 2  2024-07-01 00:00:00  2024-08-01 00:00:00   Total Geral
# 3          1277369.699          1325995.842  23316950.373
# 4          2192330.428          2245006.626  43241244.267
#
# [5 rows x 22 columns]
#
# Últimas linhas:
#                                            Unnamed: 0    Unnamed: 1  \
# 9   23 - FABRICAÇÃO DE PRODUTOS DE MINERAIS NÃO-ME...   1086588.774
# 10                                    24 - METALURGIA   3803046.864
# 11  25 - FABRICAÇÃO DE PRODUTOS DE METAL, EXCETO M...    341659.464
# 12  29 - FABRICAÇÃO DE VEÍCULOS AUTOMOTORES, REBOQ...    505843.749
# 13                                        Total Geral  12504433.947
#
#       Unnamed: 2    Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6  \
# 9     1065995.77   1159092.696   1179762.862   1174030.449   1189391.427
# 10   3679729.377   4111679.105    3934597.33   4073937.595    3892181.39
# 11    353090.881    359920.447    381562.592    368463.236     376634.63
# 12    540851.319    562930.353    580685.411    553515.704    565321.591
# 13  12317415.783  13282085.303  13190572.232  13196713.387  13065735.683
#
#       Unnamed: 7    Unnamed: 8    Unnamed: 9  ...   Unnamed: 12   Unnamed: 13  \
# 9    1212143.626   1254235.648   1227699.402  ...   1118384.336   1110459.501
# 10   4067907.002   4105133.737   3897683.739  ...   3926619.441   4022510.813
# 11    365552.397    374072.806    376331.083  ...     353933.69    325914.374
# 12    542864.082    557425.668     577812.69  ...    528885.957    484034.193
# 13  13123965.462  13454561.414  13297865.908  ...  13055986.063  12926916.568
#
#      Unnamed: 14   Unnamed: 15   Unnamed: 16   Unnamed: 17  Unnamed: 18  \
# 9     1086219.12   1177887.436    1199809.82   1216998.259  1190657.434
# 10   3882757.372   4133439.836   4113669.099    4244697.42  4223259.374
# 11    353667.946    390657.573    388467.259    395965.351   386253.793
# 12    533437.947    572332.721    595176.657    585520.921   560008.804
# 13  12887047.476  13513092.073  13582109.827  13778188.237   13657503.3
#
#      Unnamed: 19   Unnamed: 20    Unnamed: 21
# 9    1265932.772    1326393.36   23635739.339
# 10   4342248.556   4376068.417   81033113.055
# 11    390675.425    411236.016    7445458.033
# 12    573928.768    596344.652   11149472.421
# 13  14050723.894  14447163.486  266271359.563
#
# [5 rows x 22 columns]
#
# Resumo estatístico:
#              Unnamed: 0         Unnamed: 1           Unnamed: 2  \
# count                13                 13                   12
# unique               13                 13                   12
# top     Soma de Consumo  Rótulos de Coluna  2023-02-01 00:00:00
# freq                  1                  1                    1
#
#                  Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# count                    12                   12                   12
# unique                   12                   12                   12
# top     2023-03-01 00:00:00  2023-04-01 00:00:00  2023-05-01 00:00:00
# freq                      1                    1                    1
#
#                  Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# count                    12                   12                   12
# unique                   12                   12                   12
# top     2023-06-01 00:00:00  2023-07-01 00:00:00  2023-08-01 00:00:00
# freq                      1                    1                    1
#
#                  Unnamed: 9  ...          Unnamed: 12          Unnamed: 13  \
# count                    12  ...                   12                   12
# unique                   12  ...                   12                   12
# top     2023-09-01 00:00:00  ...  2023-12-01 00:00:00  2024-01-01 00:00:00
# freq                      1  ...                    1                    1
#
#                 Unnamed: 14          Unnamed: 15          Unnamed: 16  \
# count                    12                   12                   12
# unique                   12                   12                   12
# top     2024-02-01 00:00:00  2024-03-01 00:00:00  2024-04-01 00:00:00
# freq                      1                    1                    1
#
#                 Unnamed: 17          Unnamed: 18          Unnamed: 19  \
# count                    12                   12                   12
# unique                   12                   12                   12
# top     2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00
# freq                      1                    1                    1
#
#                 Unnamed: 20  Unnamed: 21
# count                    12           12
# unique                   12           12
# top     2024-08-01 00:00:00  Total Geral
# freq                      1            1
#
# [4 rows x 22 columns]
#
# Informações dos dados:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   13 non-null     object
#  1   Unnamed: 1   13 non-null     object
#  2   Unnamed: 2   12 non-null     object
#  3   Unnamed: 3   12 non-null     object
#  4   Unnamed: 4   12 non-null     object
#  5   Unnamed: 5   12 non-null     object
#  6   Unnamed: 6   12 non-null     object
#  7   Unnamed: 7   12 non-null     object
#  8   Unnamed: 8   12 non-null     object
#  9   Unnamed: 9   12 non-null     object
#  10  Unnamed: 10  12 non-null     object
#  11  Unnamed: 11  12 non-null     object
#  12  Unnamed: 12  12 non-null     object
#  13  Unnamed: 13  12 non-null     object
#  14  Unnamed: 14  12 non-null     object
#  15  Unnamed: 15  12 non-null     object
#  16  Unnamed: 16  12 non-null     object
#  17  Unnamed: 17  12 non-null     object
#  18  Unnamed: 18  12 non-null     object
#  19  Unnamed: 19  12 non-null     object
#  20  Unnamed: 20  12 non-null     object
#  21  Unnamed: 21  12 non-null     object
# dtypes: object(22)
# memory usage: 2.5+ KB
# None
#
# Valores únicos por coluna:
# {'Unnamed: 0': 13, 'Unnamed: 1': 13, 'Unnamed: 2': 12, 'Unnamed: 3': 12, 'Unnamed: 4': 12, 'Unnamed: 5': 12, 'Unnamed: 6': 12, 'Unnamed: 7': 12, 'Unnamed: 8': 12, 'Unnamed: 9': 12, 'Unnamed: 10': 12, 'Unnamed: 11': 12, 'Unnamed: 12': 12, 'Unnamed: 13': 12, 'Unnamed: 14': 12, 'Unnamed: 15': 12, 'Unnamed: 16': 12, 'Unnamed: 17': 12, 'Unnamed: 18': 12, 'Unnamed: 19': 12, 'Unnamed: 20': 12, 'Unnamed: 21': 12}

# %%
# Caminho para o arquivo Excel
file_path = 'D:\Pastas\Infnet\Infnet - 2024.2\Projeto de bloco\TP1\Dados_abertos_Consumo_Mensal.xlsx'

# Carregar o arquivo Excel
xls = pd.ExcelFile(file_path)

# Iterar sobre cada planilha e imprimir as colunas
for sheet_name in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet_name)
    print(f"Colunas para a planilha {sheet_name}: {df.columns.tolist()}\n")
# Out:
# Colunas para a planilha CONSUMO E NUMCONS SAM: ['Data', 'DataExcel', 'Regiao', 'Sistema', 'Classe', 'TipoConsumidor', 'Consumo', 'Consumidores']
#
# Colunas para a planilha CONSUMO E NUMCONS SAM UF: ['Data', 'DataExcel', 'UF', 'Regiao', 'Sistema', 'Classe', 'TipoConsumidor', 'Consumo', 'Consumidores']
#
# Colunas para a planilha SETOR INDUSTRIAL POR RG: ['Data', 'DataExcel', 'SetorIndustrial', 'Regiao', 'Consumo']
#
# Colunas para a planilha CONSUMO_BEN_RG_1970-1989: ['Ano', 'Regiao', 'Classe', 'Consumo']
#
# Colunas para a planilha CONSUMO_ELETROBRAS_1990-2003: ['Data', 'DataExcel', 'Regiao', 'Classe', 'Consumo', 'Consumidores']
#
# Colunas para a planilha ANALISE CONS NUMCONS SAM: ['Soma de Consumo', 'Rótulos de Coluna', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21']
#
# Colunas para a planilha ANALISE CONS NUMCONS SAM UF: ['Soma de Consumo', 'DataExcel', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']
#
# Colunas para a planilha ANALISE SETOR IND POR RG: ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21']
